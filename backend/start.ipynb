# %% [markdown]
# # RAG exploration chatbot procédures

# %%
import os
from langchain_ollama import ChatOllama, OllamaEmbeddings
from langchain_community.document_loaders import PyPDFLoader, Docx2txtLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from pathlib import Path

# %%
def check_dir_exists(path: Path):
    if not path.exists():
        raise FileNotFoundError(f"Le chemin n'existe pas : {path}")
    if not path.is_dir():
        raise NotADirectoryError(f"Le chemin n'est pas un dossier : {path}")
    
check_dir_exists(Path.cwd() / ".." / "data" / "files_test")

# %% [markdown]
# ## PDF METHOD

# %%
# chargement du répertoire des PDF

pdfs = Path.cwd() / ".." / "data" / "files_test"

if not pdfs.exists():
    raise FileNotFoundError(f"Chemin introuvable: {pdfs}")
if not pdfs.is_dir():
    raise NotADirectoryError(f"Ce n'est pas un dossier: {pdfs}")

def load_docs(doc_dir: Path):
    docs = []

    doc_paths = sorted(
        list(doc_dir.rglob("*.pdf")) + list(doc_dir.rglob("*.docx")),
        key=lambda p: str(p).lower()
    )

    for path in doc_paths:
        if path.suffix.lower() == ".pdf":
            loader = PyPDFLoader(str(path))
        elif path.suffix.lower() == ".docx":
            loader = Docx2txtLoader(str(path))
        else:
            continue

        pages = loader.load()

        for d in pages:
            d.metadata["source_path"] = str(path)
            d.metadata["source_file"] = path.name
            d.metadata["file_type"] = path.suffix.lower()

        docs.extend(pages)

    return docs

raw_docs = load_docs(pdfs)
print(raw_docs[0])
# Out:
# page_content='CREATION DE COMPTE
#
#
# A réception de ce message, dans votre messagerie :
#
#
# Ouvrez-le et Cliquez sur Se connecter à Zoom
#
#
# Remplissez les 4 zones demandées : prénom, nom de famille, mot de passe, confirmation du mot de
# passe, puis cliquez sur Continuer' metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2023-06-28T11:22:33+02:00', 'author': 'Frédéric ARNAUD365', 'moddate': '2023-06-28T11:22:33+02:00', 'source': '/home/sachard/mairie/backend/../data/files_test/1 - Créer son Compte.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source_path': '/home/sachard/mairie/backend/../data/files_test/1 - Créer son Compte.pdf', 'source_file': '1 - Créer son Compte.pdf', 'file_type': '.pdf'}

# %%
from IPython.display import display, Markdown

def show_doc(doc):
    md = f"""
### Source
- Fichier : `{doc.metadata.get('source_file')}`
- Page : `{doc.metadata.get('page')}`

---

{doc.page_content}
"""
    display(Markdown(md))

show_doc(raw_docs[2])
# Out:
# ### Source
# - Fichier : `2 - Installer l'Application.pdf`
# - Page : `0`
#
# ---
#
# Installation de l’ Application
# Sur PC
#
# Ouvrez l’Explorateur de Fichiers, puis l’Emplacement CASTELNAU - COMMUN (X :)
#
#
#
# Ensuite, ouvrez successivement les dossiers Informatique, puis Utilitaires et enfin Zoom
# Vous arrivez sur cette interface :
#
#
#
# Maintenant, double-cliquez sur ZoomInstaller.exe pour débuter l’installation de l’ Application Zoom
#
# Sur la fenêtre qui s’ouvre, cliquez sur Exécuter

# %% [markdown]
# ## CHUNKING, EMBEDDINGS

# %%
raw_docs = load_docs(pdfs)

# Chunking
splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=120,
)

chunks = splitter.split_documents(raw_docs)
print("Chunks:", len(chunks))
# Out:
# Chunks: 201

# %%
#test API ollama

llm = ChatOllama(
    model="mistral",
    base_url="http://localhost:11434",
    temperature=0.2,
)

# %%
#embeddings
chunks = splitter.split_documents(raw_docs)
texts = [doc.page_content for doc in chunks]
embeddings = OllamaEmbeddings(
    model="all-minilm",
    base_url="http://localhost:11434",
)


# Pas néecessaire si on utilise FAISS.from_documents
# # vecteurs
# vectors = embeddings.embed_documents(
#     [doc.page_content for doc in chunks]
# )
# print(len(vectors), len(vectors[0]))
# Out:
# /tmp/ipykernel_28229/2464441557.py:4: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaEmbeddings``.
#   embeddings = OllamaEmbeddings(

# %%
lengths = [len(d.page_content) for d in chunks]
max_len = max(lengths)
idx = lengths.index(max_len)

print("Nb chunks:", len(chunks))
print("Max chars:", max_len)
print("Index chunk max:", idx)
print("Metadata:", chunks[idx].metadata)
print("Aperçu:", chunks[idx].page_content[:500])
# Out:
# Nb chunks: 201
# Max chars: 498
# Index chunk max: 80
# Metadata: {'producer': 'Microsoft® Word pour Microsoft\xa0365', 'creator': 'Microsoft® Word pour Microsoft\xa0365', 'creationdate': '2025-03-21T11:47:51+01:00', 'author': 'MATHIEU RESPAUT', 'moddate': '2025-03-21T11:47:51+01:00', 'source': '/mnt/u/chatbot/rag/files_test/Charte informatique 03-2025.pdf', 'total_pages': 18, 'page': 8, 'page_label': '9', 'source_path': '/mnt/u/chatbot/rag/files_test/Charte informatique 03-2025.pdf', 'source_file': 'Charte informatique 03-2025.pdf', 'file_type': '.pdf'}
# Aperçu: est imposé de ne pas les relayer. II ne doit donc pas en solliciter l'envoi en participant à des groupes de
# discussion, ou en consultant des sites, dont le caractère est proscrit, qui pourrait enregistrer ses
# coordonnées.
#  Utilisation de la messagerie électronique à des fins personnelles
# Il est considéré que tout message reçu ou envoyé à partir du poste de travail mis à la disposition de
# l'utilisateur revêt par principe un caractère professionnel. L'utilisation de la messagerie à des fins

# %%
#indexation FAISS

db = FAISS.from_documents(
    documents=chunks,
    embedding=embeddings,
)
db.save_local("./faiss_index")

# Chargement de l'index FAISS
db = FAISS.load_local(
    "./faiss_index",
    embeddings,
    allow_dangerous_deserialization=True
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 3
#       1 #indexation FAISS
# ----> 3 db = FAISS.from_documents(chunks, embeddings)
#       4 db.save_local("./faiss_index")
#       6 # Chargement de l'index FAISS
#
# File ~/mairie/.venv/lib/python3.12/site-packages/langchain_core/vectorstores/base.py:813, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     810     if any(ids):
#     811         kwargs["ids"] = ids
# --> 813 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File ~/mairie/.venv/lib/python3.12/site-packages/langchain_community/vectorstores/faiss.py:1043, in FAISS.from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#    1016 @classmethod
#    1017 def from_texts(
#    1018     cls,
#    (...)   1023     **kwargs: Any,
#    1024 ) -> FAISS:
#    1025     """Construct FAISS wrapper from raw documents.
#    1026
#    1027     This is a user friendly interface that:
#    (...)   1041             faiss = FAISS.from_texts(texts, embeddings)
#    1042     """
# -> 1043     embeddings = embedding.embed_documents(texts)
#    1044     return cls.__from(
#    1045         texts,
#    1046         embeddings,
#    (...)   1050         **kwargs,
#    1051     )
#
# File ~/mairie/.venv/lib/python3.12/site-packages/langchain_community/embeddings/ollama.py:214, in OllamaEmbeddings.embed_documents(self, texts)
#     205 """Embed documents using an Ollama deployed embedding model.
#     206
#     207 Args:
#    (...)    211     List of embeddings, one for each text.
#     212 """
#     213 instruction_pairs = [f"{self.embed_instruction}{text}" for text in texts]
# --> 214 embeddings = self._embed(instruction_pairs)
#     215 return embeddings
#
# File ~/mairie/.venv/lib/python3.12/site-packages/langchain_community/embeddings/ollama.py:202, in OllamaEmbeddings._embed(self, input)
#     200 else:
#     201     iter_ = input
# --> 202 return [self._process_emb_response(prompt) for prompt in iter_]
#
# File ~/mairie/.venv/lib/python3.12/site-packages/langchain_community/embeddings/ollama.py:176, in OllamaEmbeddings._process_emb_response(self, input)
#     173     raise ValueError(f"Error raised by inference endpoint: {e}")
#     175 if res.status_code != 200:
# --> 176     raise ValueError(
#     177         "Error raised by inference API HTTP code: %s, %s"
#     178         % (res.status_code, res.text)
#     179     )
#     180 try:
#     181     t = res.json()
#
# ValueError: Error raised by inference API HTTP code: 500, {"error":"the input length exceeds the context length"}

# %% [markdown]
# ## DEBUG

# %%
# debug retrieval RAG

def debug_retrieval(db, question, k=5):
    docs = db.similarity_search(question, k=k)
    for i, d in enumerate(docs, 1):
        src = d.metadata.get("source_file") or d.metadata.get("source")
        page = d.metadata.get("page")
        print(f"\n--- {i}. {src} page {page} ---")
        print(d.page_content[:500])
    return docs
debug_retrieval(db, "comment se connecter au wifi résidents ?", k=5)
# Out:
# --- 1. Wifi Mairie - Procédure Connexion.pdf page 1 ---
# W I F I     M A I R I E
#
# DIRECTION DU SYSTEME
# D’INFORMATION  WIFI MAIRIE
#
#
#
# 5. Dans cette nouvelle fenêtre, cochez se connecter automatiquement et cliquez sur Se connecter
#
#
#
#
#
# 6. Puis, cliquez encore sur Se
# connecter
#
# --- 2. Wifi Mairie - Procédure Connexion.pdf page 4 ---
# W I F I     M A I R I E
#
# DIRECTION DU SYSTEME
# D’INFORMATION  WIFI MAIRIE
#
# Une fois le PC redémarré,
#
#
# Vous obtenez cette fenêtre
#
# Tout est Ok, vous êtes bien connecté au WIFI_MAIRIE
#
# --- 3. Wifi Mairie - Procédure Connexion.pdf page 0 ---
# W I F I     M A I R I E
#
# DIRECTION DU SYSTEME
# D’INFORMATION  WIFI MAIRIE
# PROCEDURE DE CONNEXION
#
#
# 1. Allumez votre ordinateur (sur votre session utilisateur)
#
# 2. Cliquez sur l’icône du Wifi dans la barre des tâches (en bas à droite de l’écran)
#
#
#
#
#
# La fenêtre
# suivante
#
# s’ouvre
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 3.
#
#  Cliquez sur
# Wi
# -
# Fi
#
#
# 4.
#
#  Dans la liste qui apparait, cliquez sur
# WIFI_MAIRIE
#
# --- 4. Wifi Mairie - Procédure Connexion.pdf page 3 ---
# W I F I     M A I R I E
#
# DIRECTION DU SYSTEME
# D’INFORMATION  WIFI MAIRIE
#
# Vous revenez sur la fenêtre précédente, cliquez de nouveau sur Se connecter
#
#
#
#
# Cette fenêtre apparait
#
#
#
# Sans rien faire dessus, Redémarrez votre ordinateur.
#
# --- 5. Procédure connexion WiFI_RESIDENTS.pdf page 0 ---
# ou tablettes récentes)
# 1- Cliquer sur WiFi_RESIDENTS           2- Cliquer sur afficher plus                    3- Cliquer Type d’adresse
# MAC
#
#
#
#
#
#
#
#
#
#
#
# 4-  Sélectionner Adresse Mac             5- Renseigner le code
# du téléphone
# [Document(id='03e4cc9e-1e17-4b41-864c-d309eb9fc116', metadata={'producer': 'Microsoft® Word pour Microsoft\xa0365', 'creator': 'Microsoft® Word pour Microsoft\xa0365', 'creationdate': '2024-12-04T08:15:30+01:00', 'author': 'BELLOC Arnaud', 'moddate': '2024-12-04T08:15:30+01:00', 'source': '/mnt/u/pdfs/Wifi Mairie - Procédure Connexion.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2', 'source_path': '/mnt/u/pdfs/Wifi Mairie - Procédure Connexion.pdf', 'source_file': 'Wifi Mairie - Procédure Connexion.pdf'}, page_content='W I F I     M A I R I E    \n  \nDIRECTION DU SYSTEME \nD’INFORMATION  WIFI MAIRIE  \n  \n  \n  \n5. Dans cette nouvelle fenêtre, cochez se connecter automatiquement et cliquez sur Se connecter  \n \n  \n  \n  \n  \n6. Puis, cliquez encore sur Se \nconnecter'),
#  Document(id='6183dc32-a322-47aa-b051-ca3616973ae8', metadata={'producer': 'Microsoft® Word pour Microsoft\xa0365', 'creator': 'Microsoft® Word pour Microsoft\xa0365', 'creationdate': '2024-12-04T08:15:30+01:00', 'author': 'BELLOC Arnaud', 'moddate': '2024-12-04T08:15:30+01:00', 'source': '/mnt/u/pdfs/Wifi Mairie - Procédure Connexion.pdf', 'total_pages': 5, 'page': 4, 'page_label': '5', 'source_path': '/mnt/u/pdfs/Wifi Mairie - Procédure Connexion.pdf', 'source_file': 'Wifi Mairie - Procédure Connexion.pdf'}, page_content='W I F I     M A I R I E    \n  \nDIRECTION DU SYSTEME \nD’INFORMATION  WIFI MAIRIE  \n  \nUne fois le PC redémarré,   \n  \n  \nVous obtenez cette fenêtre  \n  \nTout est Ok, vous êtes bien connecté au WIFI_MAIRIE'),
#  Document(id='25eff76c-c457-48cb-b50e-dda96325c637', metadata={'producer': 'Microsoft® Word pour Microsoft\xa0365', 'creator': 'Microsoft® Word pour Microsoft\xa0365', 'creationdate': '2024-12-04T08:15:30+01:00', 'author': 'BELLOC Arnaud', 'moddate': '2024-12-04T08:15:30+01:00', 'source': '/mnt/u/pdfs/Wifi Mairie - Procédure Connexion.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1', 'source_path': '/mnt/u/pdfs/Wifi Mairie - Procédure Connexion.pdf', 'source_file': 'Wifi Mairie - Procédure Connexion.pdf'}, page_content='W I F I     M A I R I E    \n  \nDIRECTION DU SYSTEME \nD’INFORMATION  WIFI MAIRIE  \nPROCEDURE DE CONNEXION   \n \n \n1. Allumez votre ordinateur (sur votre session utilisateur)  \n  \n2. Cliquez sur l’icône du Wifi dans la barre des tâches (en bas à droite de l’écran)  \n \n  \n  \n  \n  \nLa fenêtre  \nsuivante \n  \ns’ouvre \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n3. \n  \n Cliquez sur  \nWi \n- \nFi \n  \n  \n4. \n  \n Dans la liste qui apparait, cliquez sur  \nWIFI_MAIRIE'),
#  Document(id='38fa06aa-59ee-48ca-a95a-2f2ed150bf04', metadata={'producer': 'Microsoft® Word pour Microsoft\xa0365', 'creator': 'Microsoft® Word pour Microsoft\xa0365', 'creationdate': '2024-12-04T08:15:30+01:00', 'author': 'BELLOC Arnaud', 'moddate': '2024-12-04T08:15:30+01:00', 'source': '/mnt/u/pdfs/Wifi Mairie - Procédure Connexion.pdf', 'total_pages': 5, 'page': 3, 'page_label': '4', 'source_path': '/mnt/u/pdfs/Wifi Mairie - Procédure Connexion.pdf', 'source_file': 'Wifi Mairie - Procédure Connexion.pdf'}, page_content='W I F I     M A I R I E    \n  \nDIRECTION DU SYSTEME \nD’INFORMATION  WIFI MAIRIE  \n  \nVous revenez sur la fenêtre précédente, cliquez de nouveau sur Se connecter   \n \n  \n  \n  \nCette fenêtre apparait  \n  \n  \n  \nSans rien faire dessus, Redémarrez votre ordinateur.'),
#  Document(id='1709ed9e-8440-43f3-926e-4c49ce026811', metadata={'producer': 'Microsoft® Word pour Microsoft\xa0365', 'creator': 'Microsoft® Word pour Microsoft\xa0365', 'creationdate': '2024-03-13T11:03:55+01:00', 'author': 'Valentin DESHOULLIERS', 'moddate': '2024-03-13T11:03:55+01:00', 'source': '/mnt/u/pdfs/Procédure connexion WiFI_RESIDENTS.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source_path': '/mnt/u/pdfs/Procédure connexion WiFI_RESIDENTS.pdf', 'source_file': 'Procédure connexion WiFI_RESIDENTS.pdf'}, page_content='ou tablettes récentes) \n1- Cliquer sur WiFi_RESIDENTS           2- Cliquer sur afficher plus                    3- Cliquer Type d’adresse \nMAC                                \n \n \n \n \n \n \n \n \n \n \n \n4-  Sélectionner Adresse Mac             5- Renseigner le code \ndu téléphone')]

# %% [markdown]
# ## EVAL

# %%
# eval retrieval RAG

question = "comment se connecter au wifi résidents ?"

eval_set = [
  {
    "question": "comment obtenir le code pour se connecter au wifi résidents ?",
    "gold_snippet": "demander à l'accueil de l'ehpad",
  },
  {
    "question": "que dois je faire sur téléphone ou tablette ?",
    "gold_snippet": "désactiver l'option 'utiliser une adresse mac aléatoire'",
  },
]

def recall_at_k(db, eval_set, k=5):
    hits = 0
    for e in eval_set:
        docs = db.similarity_search(e["question"], k=k)
        combined = " ".join(d.page_content.lower() for d in docs)
        if e["gold_snippet"].lower() in combined:
            hits += 1
    return hits / len(eval_set)

print("Recall@5:", recall_at_k(db, eval_set, k=5))
print("Recall@10:", recall_at_k(db, eval_set, k=10))
# Out:
# Recall@5: 0.0
# Recall@10: 0.0

# %%
question = "comment se connecter au wifi résidents ?"
for doc in db.similarity_search(question, k=5):
    print(doc.metadata.get("source"), doc.metadata.get("page"))
    print(doc.page_content[:200])
# Out:
# /mnt/u/pdfs/Wifi Mairie - Procédure Connexion.pdf 1
# W I F I     M A I R I E
#
# DIRECTION DU SYSTEME
# D’INFORMATION  WIFI MAIRIE
#
#
#
# 5. Dans cette nouvelle fenêtre, cochez se connecter automatiquement et cliquez sur Se connecter
#
#
#
#
#
# /mnt/u/pdfs/Wifi Mairie - Procédure Connexion.pdf 4
# W I F I     M A I R I E
#
# DIRECTION DU SYSTEME
# D’INFORMATION  WIFI MAIRIE
#
# Une fois le PC redémarré,
#
#
# Vous obtenez cette fenêtre
#
# Tout est Ok, vous êtes bien connecté au WIFI_MAI
# /mnt/u/pdfs/Wifi Mairie - Procédure Connexion.pdf 0
# W I F I     M A I R I E
#
# DIRECTION DU SYSTEME
# D’INFORMATION  WIFI MAIRIE
# PROCEDURE DE CONNEXION
#
#
# 1. Allumez votre ordinateur (sur votre session utilisateur)
#
# 2. Cliquez sur l’icône
# /mnt/u/pdfs/Wifi Mairie - Procédure Connexion.pdf 3
# W I F I     M A I R I E
#
# DIRECTION DU SYSTEME
# D’INFORMATION  WIFI MAIRIE
#
# Vous revenez sur la fenêtre précédente, cliquez de nouveau sur Se connecter
#
#
#
#
# Cette fenêtre apparait
#
# /mnt/u/pdfs/Procédure connexion WiFI_RESIDENTS.pdf 0
# ou tablettes récentes)
# 1- Cliquer sur WiFi_RESIDENTS           2- Cliquer sur afficher plus                    3- Cliquer Type d’adresse
# MAC
#
#
#
#
#
#
#
#
#
#
#
# 4-

# %% [markdown]
# ## TESTS

# %%
# prompt
prompt = ChatPromptTemplate.from_template("""
Tu es un assistant qui répond UNIQUEMENT à partir du contexte.
Si la réponse n'est pas dans le contexte, dis "Je ne sais pas".

Contexte:
{context}

Question:
{question}

Réponse (sans références):
""")

#Test
query = "Comment me connecter au wifi résidents?"
results = db.similarity_search(query, k=5)

# for i, doc in enumerate(results, start=1):
#     src = doc.metadata.get("source")
#     page = doc.metadata.get("page")
#     print(f"\n--- Résultat {i} ({src}, page {page}) ---")
#     print(doc.page_content[:400])

# Retriever
retriever = db.as_retriever(search_kwargs={"k": 5})

# Chaîne RAG
rag_chain = (
    {
        "context": retriever,
        "question": RunnablePassthrough(),
    }
    | prompt
    | llm
)

result = rag_chain.invoke("Comment me connecter au wifi résidents?")
print(result.content)
# Out:
#  Pour se connecter au WiFi des résidents, suivez les étapes suivantes :
#
# 1. Allumez votre ordinateur (sur votre session utilisateur).
# 2. Cliquez sur l’icône du Wifi dans la barre des tâches (en bas à droite de l’écran).
# 3. Dans la liste qui apparait, cliquez sur WiFi_RESIDENTS.
# 4. Cliquer sur afficher plus.
# 5. Sélectionner Adresse Mac.
# 6. Renseigner le code du téléphone.

# %%
# prompt
prompt = ChatPromptTemplate.from_template("""
Tu es un assistant qui répond UNIQUEMENT à partir du contexte.
Si la réponse n'est pas dans le contexte, dis "Je ne sais pas".

Contexte:
{context}

Question:
{question}

Réponse (sans références):
""")

#Test
query = "Quelle est l'étape 7 de la procédure indiquée ?"
results = db.similarity_search(query, k=5)

for i, doc in enumerate(results, start=1):
    src = doc.metadata.get("source")
    page = doc.metadata.get("page")
    print(f"\n--- Résultat {i} ({src}, page {page}) ---")
    print(doc.page_content[:400])

# Retriever
retriever = db.as_retriever(search_kwargs={"k": 5})

# Chaîne RAG
rag_chain = (
    {
        "context": retriever,
        "question": RunnablePassthrough(),
    }
    | prompt
    | llm
)

result = rag_chain.invoke("Comment me connecter au wifi mairie?")
print(result.content)
# Out:
# --- Résultat 1 (/mnt/u/pdfs/Procédure connexion WiFI_RESIDENTS.pdf, page 0) ---
# AIDE CONNEXION AU WIFI_RESIDENTS
# 1ére étape : demander un code auprès de l’accueil de l’Ehpad
#
# Pour information, ce code est à usage unique. Cela signifie qu’il ne pourra être utilisé que sur 1 seul
# équipement (téléphone, tablette, ordinateur, cadre photo…)
#
# Si vous disposez de plusieurs équipements, il faudra donc demander plusieurs codes.
#
# Ce code est sans limitation de temps et de durée
#
# --- Résultat 2 (/mnt/u/pdfs/Procédure connexion WiFI_RESIDENTS.pdf, page 1) ---
# - Sur un ordinateur ou tout autre équipement
#
# 1- Sélectionner le réseau WiFI_RESIDENTS              2- Renseigner le code
#
#
#
#
#
#
#
#
#
#
# /!\ En cas de problème, merci de voir avec l’accueil de l’EHPAD qui escaladera l’incident.
#
# --- Résultat 3 (/mnt/u/pdfs/Wifi Mairie - Procédure Connexion.pdf, page 0) ---
# W I F I     M A I R I E
#
# DIRECTION DU SYSTEME
# D’INFORMATION  WIFI MAIRIE
# PROCEDURE DE CONNEXION
#
#
# 1. Allumez votre ordinateur (sur votre session utilisateur)
#
# 2. Cliquez sur l’icône du Wifi dans la barre des tâches (en bas à droite de l’écran)
#
#
#
#
#
# La fenêtre
# suivante
#
# s’ouvre
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 3.
#
#  Cliquez sur
# Wi
# -
# Fi
#
#
#
#
# --- Résultat 4 (/mnt/u/pdfs/Procédure connexion WiFI_RESIDENTS.pdf, page 0) ---
# ou tablettes récentes)
# 1- Cliquer sur WiFi_RESIDENTS           2- Cliquer sur afficher plus                    3- Cliquer Type d’adresse
# MAC
#
#
#
#
#
#
#
#
#
#
#
# 4-  Sélectionner Adresse Mac             5- Renseigner le code
# du téléphone
#
# --- Résultat 5 (/mnt/u/pdfs/Wifi Mairie - Procédure Connexion.pdf, page 3) ---
# W I F I     M A I R I E
#
# DIRECTION DU SYSTEME
# D’INFORMATION  WIFI MAIRIE
#
# Vous revenez sur la fenêtre précédente, cliquez de nouveau sur Se connecter
#
#
#
#
# Cette fenêtre apparait
#
#
#
# Sans rien faire dessus, Redémarrez votre ordinateur.
#  Pour vous connecter au WiFi Mairie, suivez ces étapes :
# 1. Allumez votre ordinateur (sur votre session utilisateur).
# 2. Cliquez sur l’icône du Wifi dans la barre des tâches (en bas à droite de l’écran).
# 3. Dans la liste qui apparait, cliquez sur WIFI_MAIRIE.
# 4. Une nouvelle fenêtre s'ouvre. Cochez se connecter automatiquement et cliquez sur Se connecter.
# 5. Puis, cliquez encore sur Se connecter.
